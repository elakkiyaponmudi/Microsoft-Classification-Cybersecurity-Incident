# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Elakkiya\Downloads\microsoft cybersecurity\GUIDE_Train.csv")

# %%
df
# Out:
#                     Id  OrgId  IncidentId  AlertId                 Timestamp  \
# 0         180388628218      0         612   123247  2024-06-04T06:05:15.000Z
# 1         455266534868     88         326   210035  2024-06-14T03:01:25.000Z
# 2        1056561957389    809       58352   712507  2024-06-13T04:52:55.000Z
# 3        1279900258736     92       32992   774301  2024-06-10T16:39:36.000Z
# 4         214748368522    148        4359   188041  2024-06-15T01:08:07.000Z
# ...                ...    ...         ...      ...                       ...
# 6563000   438086666193     19         669    22962  2024-06-14T07:14:03.000Z
# 6563001  1374389539213     53         161       57  2024-06-04T10:12:57.000Z
# 6563002    42949677382   1034        8477   341247  2024-06-07T19:41:27.000Z
# 6563003   472446405163     98      221782  1574158  2024-06-03T02:48:39.000Z
# 6563004   154618825712     55      179195   609463  2024-06-05T22:35:37.000Z
#
#          DetectorId  AlertTitle            Category    MitreTechniques  \
# 0                 7           6       InitialAccess                NaN
# 1                58          43        Exfiltration                NaN
# 2               423         298       InitialAccess              T1189
# 3                 2           2   CommandAndControl                NaN
# 4                 9          74           Execution                NaN
# ...             ...         ...                 ...                ...
# 6563000          92          29   CommandAndControl  T1046;T1071;T1210
# 6563001          61          44       InitialAccess        T1190;T1133
# 6563002           5        1745  SuspiciousActivity                NaN
# 6563003         160       10732             Malware                NaN
# 6563004           3           4  SuspiciousActivity                NaN
#
#           IncidentGrade  ... ResourceType Roles OSFamily OSVersion  \
# 0          TruePositive  ...          NaN   NaN        5        66
# 1         FalsePositive  ...          NaN   NaN        5        66
# 2         FalsePositive  ...          NaN   NaN        5        66
# 3        BenignPositive  ...          NaN   NaN        5        66
# 4          TruePositive  ...          NaN   NaN        5        66
# ...                 ...  ...          ...   ...      ...       ...
# 6563000  BenignPositive  ...          NaN   NaN        5        66
# 6563001   FalsePositive  ...          NaN   NaN        5        66
# 6563002    TruePositive  ...          NaN   NaN        5        66
# 6563003             NaN  ...          NaN   NaN        0         0
# 6563004    TruePositive  ...          NaN   NaN        5         6
#
#          AntispamDirection  SuspicionLevel  LastVerdict  CountryCode   State  \
# 0                      NaN             NaN          NaN         31.0     6.0
# 1                      NaN             NaN          NaN        242.0  1445.0
# 2                      NaN      Suspicious   Suspicious        242.0  1445.0
# 3                      NaN      Suspicious   Suspicious        242.0  1445.0
# 4                      NaN             NaN          NaN        242.0  1445.0
# ...                    ...             ...          ...          ...     ...
# 6563000                NaN             NaN          NaN        242.0  1445.0
# 6563001                NaN             NaN          NaN        242.0  1445.0
# 6563002                NaN             NaN          NaN        242.0  1445.0
# 6563003                NaN      Suspicious   Suspicious        242.0  1445.0
# 6563004                NaN             NaN          NaN          NaN     NaN
#
#             City
# 0            3.0
# 1        10630.0
# 2        10630.0
# 3        10630.0
# 4        10630.0
# ...          ...
# 6563000  10630.0
# 6563001  10630.0
# 6563002  10630.0
# 6563003  10630.0
# 6563004      NaN
#
# [6563005 rows x 45 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6563005 entries, 0 to 6563004
# Data columns (total 45 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Id                  int64
#  1   OrgId               int64
#  2   IncidentId          int64
#  3   AlertId             int64
#  4   Timestamp           object
#  5   DetectorId          int64
#  6   AlertTitle          int64
#  7   Category            object
#  8   MitreTechniques     object
#  9   IncidentGrade       object
#  10  ActionGrouped       object
#  11  ActionGranular      object
#  12  EntityType          object
#  13  EvidenceRole        object
#  14  DeviceId            int64
#  15  Sha256              int64
#  16  IpAddress           int64
#  17  Url                 int64
#  18  AccountSid          int64
#  19  AccountUpn          int64
#  20  AccountObjectId     int64
#  21  AccountName         int64
#  22  DeviceName          int64
#  23  NetworkMessageId    int64
#  24  EmailClusterId      float64
#  25  RegistryKey         int64
#  26  RegistryValueName   int64
#  27  RegistryValueData   int64
#  28  ApplicationId       int64
#  29  ApplicationName     int64
#  30  OAuthApplicationId  int64
#  31  ThreatFamily        object
#  32  FileName            int64
#  33  FolderPath          int64
#  34  ResourceIdName      int64
#  35  ResourceType        object
#  36  Roles               object
#  37  OSFamily            int64
#  38  OSVersion           int64
#  39  AntispamDirection   object
#  40  SuspicionLevel      object
#  41  LastVerdict         object
#  42  CountryCode         float64
#  43  State               float64
#  44  City                float64
# dtypes: float64(4), int64(27), object(14)
# memory usage: 2.2+ GB

# %%
# Display the first few rows of the dataset
print(df.head())

# Check for missing values
missing_values = df.isnull().sum()
print(missing_values)

# Summary statistics for numerical columns
print(df.describe())

# Summary statistics for categorical columns
print(df.describe(include=['object']))

# Unique values in each column
unique_values = df.nunique()
print(unique_values)
# Out:
#               Id  OrgId  IncidentId  AlertId                 Timestamp  \
# 0   180388628218      0         612   123247  2024-06-04T06:05:15.000Z
# 1   455266534868     88         326   210035  2024-06-14T03:01:25.000Z
# 2  1056561957389    809       58352   712507  2024-06-13T04:52:55.000Z
# 3  1279900258736     92       32992   774301  2024-06-10T16:39:36.000Z
# 4   214748368522    148        4359   188041  2024-06-15T01:08:07.000Z
#
#    DetectorId  AlertTitle           Category MitreTechniques   IncidentGrade  \
# 0           7           6      InitialAccess             NaN    TruePositive
# 1          58          43       Exfiltration             NaN   FalsePositive
# 2         423         298      InitialAccess           T1189   FalsePositive
# 3           2           2  CommandAndControl             NaN  BenignPositive
# 4           9          74          Execution             NaN    TruePositive
#
#    ... ResourceType Roles OSFamily OSVersion  AntispamDirection  \
# 0  ...          NaN   NaN        5        66                NaN
# 1  ...          NaN   NaN        5        66                NaN
# 2  ...          NaN   NaN        5        66                NaN
# 3  ...          NaN   NaN        5        66                NaN
# 4  ...          NaN   NaN        5        66                NaN
#
#    SuspicionLevel  LastVerdict  CountryCode   State     City
# 0             NaN          NaN         31.0     6.0      3.0
# 1             NaN          NaN        242.0  1445.0  10630.0
# 2      Suspicious   Suspicious        242.0  1445.0  10630.0
# 3      Suspicious   Suspicious        242.0  1445.0  10630.0
# 4             NaN          NaN        242.0  1445.0  10630.0
#
# [5 rows x 45 columns]
# Id                          0
# OrgId                       0
# IncidentId                  0
# AlertId                     0
# Timestamp                   0
# DetectorId                  0
# AlertTitle                  0
# Category                    0
# MitreTechniques       3771020
# IncidentGrade           35353
# ActionGrouped         6524451
# ActionGranular        6524451
# EntityType                  0
# EvidenceRole                0
# DeviceId                    0
# Sha256                      0
# IpAddress                   0
# Url                         0
# AccountSid                  0
# AccountUpn                  0
# AccountObjectId             0
# AccountName                 0
# DeviceName                  0
# NetworkMessageId            0
# EmailClusterId        6496258
# RegistryKey                 0
# RegistryValueName           0
# RegistryValueData           0
# ApplicationId               0
# ApplicationName             0
# OAuthApplicationId          0
# ThreatFamily          6511303
# FileName                    0
# FolderPath                  0
# ResourceIdName              0
# ResourceType          6558151
# Roles                 6412781
# OSFamily                    0
# OSVersion                   0
# AntispamDirection     6440962
# SuspicionLevel        5567480
# LastVerdict           5022710
# CountryCode                 1
# State                       1
# City                        1
# dtype: int64
#                  Id         OrgId    IncidentId       AlertId    DetectorId  \
# count  6.563005e+06  6.563005e+06  6.563005e+06  6.563005e+06  6.563005e+06
# mean   8.426641e+11  1.814676e+02  7.065033e+04  4.064818e+05  1.107473e+02
# std    4.963196e+11  3.864829e+02  1.208334e+05  4.591986e+05  4.355144e+02
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    4.123169e+11  1.000000e+01  5.040000e+02  2.326300e+04  2.000000e+00
# 50%    8.418136e+11  4.500000e+01  1.033300e+04  2.166180e+05  9.000000e+00
# 75%    1.271310e+12  1.710000e+02  8.428100e+04  6.716310e+05  4.500000e+01
# max    1.709397e+12  6.147000e+03  5.997060e+05  1.721455e+06  9.521000e+03
#
#          AlertTitle      DeviceId        Sha256     IpAddress           Url  \
# count  6.563005e+06  6.563005e+06  6.563005e+06  6.563005e+06  6.563005e+06
# mean   2.946201e+03  9.566793e+04  1.287138e+05  2.857520e+05  1.503284e+05
# std    1.145308e+04  1.634535e+04  3.399902e+04  1.412252e+05  3.751373e+04
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.000000e+00  9.879900e+04  1.382680e+05  3.606060e+05  1.603960e+05
# 50%    1.100000e+01  9.879900e+04  1.382680e+05  3.606060e+05  1.603960e+05
# 75%    1.800000e+02  9.879900e+04  1.382680e+05  3.606060e+05  1.603960e+05
# max    1.131740e+05  9.879900e+04  1.382680e+05  3.606060e+05  1.603960e+05
#
#        ...  ApplicationName  OAuthApplicationId      FileName    FolderPath  \
# count  ...     6.563005e+06        6.563005e+06  6.563005e+06  6.563005e+06
# mean   ...     3.342768e+03        8.807927e+02  2.622493e+05  1.076172e+05
# std    ...     5.103996e+02        1.299465e+01  8.155125e+04  3.220774e+04
# min    ...     0.000000e+00        0.000000e+00  0.000000e+00  0.000000e+00
# 25%    ...     3.421000e+03        8.810000e+02  2.895730e+05  1.176680e+05
# 50%    ...     3.421000e+03        8.810000e+02  2.895730e+05  1.176680e+05
# 75%    ...     3.421000e+03        8.810000e+02  2.895730e+05  1.176680e+05
# max    ...     3.421000e+03        8.810000e+02  2.895730e+05  1.176680e+05
#
#        ResourceIdName      OSFamily     OSVersion   CountryCode         State  \
# count    6.563005e+06  6.563005e+06  6.563005e+06  6.563004e+06  6.563004e+06
# mean     3.583460e+03  4.898797e+00  6.465903e+01  2.236787e+02  1.351475e+03
# std      9.057799e+01  7.026329e-01  9.303214e+00  6.279210e+01  3.510114e+02
# min      0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%      3.586000e+03  5.000000e+00  6.600000e+01  2.420000e+02  1.445000e+03
# 50%      3.586000e+03  5.000000e+00  6.600000e+01  2.420000e+02  1.445000e+03
# 75%      3.586000e+03  5.000000e+00  6.600000e+01  2.420000e+02  1.445000e+03
# max      3.586000e+03  5.000000e+00  6.600000e+01  2.420000e+02  1.445000e+03
#
#                City
# count  6.563004e+06
# mean   9.936069e+03
# std    2.607108e+03
# min    0.000000e+00
# 25%    1.063000e+04
# 50%    1.063000e+04
# 75%    1.063000e+04
# max    1.063000e+04
#
# [8 rows x 31 columns]
#                        Timestamp       Category  MitreTechniques  \
# count                    6563005        6563005          2791985
# unique                    749546             20             1182
# top     2024-06-12T01:27:49.000Z  InitialAccess  T1078;T1078.004
# freq                        7797        2960257           934551
#
#          IncidentGrade   ActionGrouped  \
# count          6527652           38554
# unique               3               3
# top     BenignPositive  ContainAccount
# freq           2834558           36950
#
#                                     ActionGranular EntityType EvidenceRole  \
# count                                        38554    6563005      6563005
# unique                                          16         33            2
# top     update stsrefreshtokenvalidfrom timestamp.         Ip      Related
# freq                                         14792    1504133      3591662
#
#        ThreatFamily     ResourceType       Roles AntispamDirection  \
# count         51702             4854      150224            122043
# unique         1604               25           9                 5
# top           Phish  Virtual Machine  Contextual           Inbound
# freq           2459             2836       89872            110930
#
#        SuspicionLevel LastVerdict
# count          995525     1540295
# unique              2           5
# top        Suspicious  Suspicious
# freq           994498      967040
# Id                     703633
# OrgId                    5716
# IncidentId             454139
# AlertId               1234845
# Timestamp              749546
# DetectorId               8214
# AlertTitle              83908
# Category                   20
# MitreTechniques          1182
# IncidentGrade               3
# ActionGrouped               3
# ActionGranular             16
# EntityType                 33
# EvidenceRole                2
# DeviceId                64618
# Sha256                  87962
# IpAddress              234479
# Url                    103195
# AccountSid             311828
# AccountUpn             459029
# AccountObjectId        301043
# AccountName            319330
# DeviceName              95676
# NetworkMessageId       311339
# EmailClusterId          21175
# RegistryKey              1110
# RegistryValueName         460
# RegistryValueData         590
# ApplicationId            1345
# ApplicationName          2112
# OAuthApplicationId        565
# ThreatFamily             1604
# FileName               176413
# FolderPath              71988
# ResourceIdName           1851
# ResourceType               25
# Roles                       9
# OSFamily                    6
# OSVersion                  53
# AntispamDirection           5
# SuspicionLevel              2
# LastVerdict                 5
# CountryCode               230
# State                    1270
# City                     8141
# dtype: int64

# %%
# Distribution of a specific categorical column
print(df['Category'].value_counts())
print(df['IncidentGrade'].value_counts())
print(df['ActionGrouped'].value_counts())

# Distribution of numerical columns
print(df['Timestamp'].value_counts())
# Out:
# Category
# InitialAccess          2960257
# Exfiltration           1088300
# SuspiciousActivity      693075
# CommandAndControl       569487
# Impact                  518267
# CredentialAccess        207060
# Execution               184597
# Malware                  99361
# Discovery                88960
# Persistence              50121
# DefenseEvasion           32146
# LateralMovement          28753
# Ransomware               13081
# UnwantedSoftware         12659
# Collection               10159
# PrivilegeEscalation       3287
# Exploit                   3146
# CredentialStealing         260
# WebExploit                  25
# Weaponization                4
# Name: count, dtype: int64
# IncidentGrade
# BenignPositive    2834558
# TruePositive      2292046
# FalsePositive     1401048
# Name: count, dtype: int64
# ActionGrouped
# ContainAccount           36950
# IsolateDevice             1554
# Stop Virtual Machines       50
# Name: count, dtype: int64
# Timestamp
# 2024-06-12T01:27:49.000Z    7797
# 2024-06-11T16:33:15.000Z    1857
# 2024-06-03T11:48:56.000Z    1651
# 2024-06-07T22:16:14.000Z    1031
# 2024-06-09T23:29:15.000Z    1031
#                             ...
# 2024-06-11T12:12:23.000Z       1
# 2024-06-17T01:34:46.000Z       1
# 2024-06-08T09:07:06.000Z       1
# 2024-06-06T17:12:49.000Z       1
# 2024-05-22T15:27:12.000Z       1
# Name: count, Length: 749546, dtype: int64

# %%
missing_percentage = (missing_values / len(df)) * 100
print(missing_percentage)
# Out:
# Id                     0.000000
# OrgId                  0.000000
# IncidentId             0.000000
# AlertId                0.000000
# Timestamp              0.000000
# DetectorId             0.000000
# AlertTitle             0.000000
# Category               0.000000
# MitreTechniques       57.458740
# IncidentGrade          0.538671
# ActionGrouped         99.412556
# ActionGranular        99.412556
# EntityType             0.000000
# EvidenceRole           0.000000
# DeviceId               0.000000
# Sha256                 0.000000
# IpAddress              0.000000
# Url                    0.000000
# AccountSid             0.000000
# AccountUpn             0.000000
# AccountObjectId        0.000000
# AccountName            0.000000
# DeviceName             0.000000
# NetworkMessageId       0.000000
# EmailClusterId        98.982981
# RegistryKey            0.000000
# RegistryValueName      0.000000
# RegistryValueData      0.000000
# ApplicationId          0.000000
# ApplicationName        0.000000
# OAuthApplicationId     0.000000
# ThreatFamily          99.212221
# FileName               0.000000
# FolderPath             0.000000
# ResourceIdName         0.000000
# ResourceType          99.926040
# Roles                 97.711049
# OSFamily               0.000000
# OSVersion              0.000000
# AntispamDirection     98.140440
# SuspicionLevel        84.831263
# LastVerdict           76.530644
# CountryCode            0.000015
# State                  0.000015
# City                   0.000015
# dtype: float64

# %%
# Select only numeric columns for correlation
numeric_df = df.select_dtypes(include=['int64', 'float64'])
corr_matrix = numeric_df.corr()

# %%
# Cross-tabulation for 'Category' and 'IncidentGrade'
crosstab_result = pd.crosstab(df['Category'], df['IncidentGrade'])
print(crosstab_result)
# Out:
# IncidentGrade        BenignPositive  FalsePositive  TruePositive
# Category
# Collection                     3831           4845          1282
# CommandAndControl            388351         100119         80295
# CredentialAccess              81789          49078         75856
# CredentialStealing                0            252             6
# DefenseEvasion                14851           9721          7325
# Discovery                     49215          23544         15279
# Execution                     92383          60676         31001
# Exfiltration                 745583         254237         69744
# Exploit                        1736            437           967
# Impact                       232712         118169        167361
# InitialAccess                732877         658667       1563221
# LateralMovement               18504           6163          3675
# Malware                       63402          13195         22437
# Persistence                   38649           8848          2517
# PrivilegeEscalation            2925            288            69
# Ransomware                     8661            211          3153
# SuspiciousActivity           349882          90868        246150
# UnwantedSoftware               9188           1729          1699
# Weaponization                     0              0             4
# WebExploit                       19              1             5

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Example: Distribution of IncidentGrade
sns.countplot(x='IncidentGrade', data=df)
plt.show()

# Example: Correlation heatmap
sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
numeric_columns = df.select_dtypes(include=['int64', 'float64']).columns

for col in numeric_columns:
    plt.figure(figsize=(10, 4))
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.show()
# Out:
# C:\Users\Elakkiya\Documents\Custom Office Templates\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Elakkiya\Documents\Custom Office Templates\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Elakkiya\Documents\Custom Office Templates\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Elakkiya\Documents\Custom Office Templates\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Elakkiya\Documents\Custom Office Templates\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Elakkiya\Documents\Custom Office Templates\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Elakkiya\Documents\Custom Office Templates\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Elakkiya\Documents\Custom Office Templates\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Elakkiya\Documents\Custom Office Templates\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Elakkiya\Documents\Custom Office Templates\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Elakkiya\Documents\Custom Office Templates\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Elakkiya\Documents\Custom Office Templates\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Elakkiya\Documents\Custom Office Templates\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Elakkiya\Documents\Custom Office Templates\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Elakkiya\Documents\Custom Office Templates\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Elakkiya\Documents\Custom Office Templates\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Elakkiya\Documents\Custom Office Templates\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Elakkiya\Documents\Custom Office Templates\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Elakkiya\Documents\Custom Office Templates\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Elakkiya\Documents\Custom Office Templates\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Elakkiya\Documents\Custom Office Templates\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Elakkiya\Documents\Custom Office Templates\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Elakkiya\Documents\Custom Office Templates\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Elakkiya\Documents\Custom Office Templates\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Elakkiya\Documents\Custom Office Templates\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Elakkiya\Documents\Custom Office Templates\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Elakkiya\Documents\Custom Office Templates\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Elakkiya\Documents\Custom Office Templates\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Elakkiya\Documents\Custom Office Templates\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Elakkiya\Documents\Custom Office Templates\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Elakkiya\Documents\Custom Office Templates\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import seaborn as sns
import matplotlib.pyplot as plt
categorical_columns = df.select_dtypes(include=['object']).columns

for col in categorical_columns:
    plt.figure(figsize=(10, 4))
    sns.countplot(x=col, data=df)
    plt.title(f'Distribution of {col}')
    plt.xticks(rotation=45)
    plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Count plot for the target variable to check for imbalance
sns.countplot(x='IncidentGrade', data=df)
plt.title('Class Distribution in IncidentGrade')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Identify numeric columns
numeric_columns = df.select_dtypes(include=['int64', 'float64']).columns

# Step 2: Plot boxplots for each numeric column
for col in numeric_columns:
    plt.figure(figsize=(10, 4))
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')
    plt.show()

# %%
pivot = pd.pivot_table(df, values='IncidentId', index=['Category'], columns=['IncidentGrade'], aggfunc='count')
sns.heatmap(pivot, annot=True, cmap='Blues')
plt.title('Incident Counts by Category and Grade')
plt.show()
# Out:
# C:\Users\Elakkiya\Documents\Custom Office Templates\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %%
import pandas as pd

# Display the data types of each column before conversion
print("\nData types of each column before conversion:")
print(df.dtypes)

# Convert all non-object columns to 'category' data type, leave object columns unchanged
for col in df.select_dtypes(exclude='object').columns:
    df[col] = df[col].astype('category')

# Function to replace low-frequency categories with 'Others'
def replace_with_top_categories(df, max_categories=5):
    for col in df.columns:
        if df[col].dtype.name == 'category':
            # Get value counts of the column
            value_counts = df[col].value_counts()
            
            if len(value_counts) > max_categories:
                # Identify top `max_categories` categories
                top_categories = value_counts.nlargest(max_categories).index
                # Replace all other categories with 'Others'
                df[col] = pd.Categorical(
                    df[col].apply(lambda x: x if x in top_categories else 'Others'),
                    categories=top_categories.union(['Others'])
                )
    return df

# Calculate and print the percentage of each category in all columns before replacement
for col in df.columns:
    print(f"\nCategory percentages for column {col} before replacement:")
    print(df[col].value_counts(normalize=True) * 100)

# Apply the function to replace low-frequency categories with 'Others'
df = replace_with_top_categories(df, max_categories=20)

# Calculate and print the percentage of each category in all columns after replacement
for col in df.columns:
    print(f"\nCategory percentages for column {col} after replacement:")
    print(df[col].value_counts(normalize=True) * 100)

# Display the data types of each column after conversion
print("\nData types of each column after conversion:")
print(df.dtypes)
# Out:
# Data types of each column before conversion:
# OrgId                  int64
# Timestamp             object
# DetectorId             int64
# AlertTitle             int64
# Category              object
# MitreTechniques       object
# IncidentGrade         object
# ActionGrouped         object
# ActionGranular        object
# EntityType            object
# EvidenceRole          object
# EmailClusterId       float64
# ApplicationName        int64
# ThreatFamily          object
# ResourceType          object
# Roles                 object
# OSFamily               int64
# OSVersion              int64
# AntispamDirection     object
# SuspicionLevel        object
# LastVerdict           object
# CountryCode          float64
# State                float64
# City                 float64
# dtype: object
#
# Category percentages for column OrgId before replacement:
# OrgId
# 0       8.884147
# 2       2.533032
# 1       2.210253
# 3       2.005392
# 5       1.820203
#           ...
# 5930    0.000015
# 4495    0.000015
# 5937    0.000015
# 5621    0.000015
# 6147    0.000015
# Name: proportion, Length: 5716, dtype: float64
#
# Category percentages for column Timestamp before replacement:
# Timestamp
# 2024-06-12T01:27:49.000Z    0.118802
# 2024-06-11T16:33:15.000Z    0.028295
# 2024-06-03T11:48:56.000Z    0.025156
# 2024-06-07T22:16:14.000Z    0.015709
# 2024-06-09T23:29:15.000Z    0.015709
#                               ...
# 2024-06-11T12:12:23.000Z    0.000015
# 2024-06-17T01:34:46.000Z    0.000015
# 2024-06-08T09:07:06.000Z    0.000015
# 2024-06-06T17:12:49.000Z    0.000015
# 2024-05-22T15:27:12.000Z    0.000015
# Name: proportion, Length: 749546, dtype: float64
#
# Category percentages for column DetectorId before replacement:
# DetectorId
# 0       14.001284
# 1        8.137934
# 2        6.270816
# 3        5.162833
# 4        4.331263
#           ...
# 8337     0.000015
# 8352     0.000015
# 8362     0.000015
# 8363     0.000015
# 9521     0.000015
# Name: proportion, Length: 8214, dtype: float64
#
# Category percentages for column AlertTitle before replacement:
# AlertTitle
# 0         14.001284
# 1          8.137934
# 2          6.270816
# 4          4.353113
# 3          4.331263
#             ...
# 99467      0.000015
# 99468      0.000015
# 99473      0.000015
# 99475      0.000015
# 113174     0.000015
# Name: proportion, Length: 83908, dtype: float64
#
# Category percentages for column Category before replacement:
# Category
# InitialAccess          45.105207
# Exfiltration           16.582343
# SuspiciousActivity     10.560330
# CommandAndControl       8.677229
# Impact                  7.896794
# CredentialAccess        3.154957
# Execution               2.812690
# Malware                 1.513956
# Discovery               1.355477
# Persistence             0.763690
# DefenseEvasion          0.489806
# LateralMovement         0.438107
# Ransomware              0.199314
# UnwantedSoftware        0.192884
# Collection              0.154792
# PrivilegeEscalation     0.050084
# Exploit                 0.047935
# CredentialStealing      0.003962
# WebExploit              0.000381
# Weaponization           0.000061
# Name: proportion, dtype: float64
#
# Category percentages for column MitreTechniques before replacement:
# MitreTechniques
# T1078;T1078.004                                    33.472637
# T1566.002                                          20.111426
# T1566                                              16.279672
# T1133                                               3.591781
# T1566.001                                           3.389954
#                                                      ...
# T1055;T1055.002;T1055.003;T1055.012;T1078;T1106     0.000036
# T0814                                               0.000036
# T1021.002;T1204;T1570                               0.000036
# T1484;T1484.001                                     0.000036
# T1068;T1548                                         0.000036
# Name: proportion, Length: 1182, dtype: float64
#
# Category percentages for column IncidentGrade before replacement:
# IncidentGrade
# BenignPositive    43.423853
# TruePositive      35.112871
# FalsePositive     21.463277
# Name: proportion, dtype: float64
#
# Category percentages for column ActionGrouped before replacement:
# ActionGrouped
# ContainAccount           95.839602
# IsolateDevice             4.030710
# Stop Virtual Machines     0.129688
# Name: proportion, dtype: float64
#
# Category percentages for column ActionGranular before replacement:
# ActionGranular
# update stsrefreshtokenvalidfrom timestamp.    38.366966
# account password changed                      25.156923
# change user password.                         24.075323
# isolateresponse                                3.659802
# account disabled                               3.491207
# disable account.                               2.043886
# reset user password.                           1.561446
# forcepasswordresetremediation                  0.383877
# quarantinefile                                 0.370908
# msecidentitiesconfirmusercompromised           0.241220
# disableuser                                    0.199720
# msecidentitiessuspenduser                      0.163407
# delete virtualmachines                         0.129688
# account deleted                                0.088188
# delete user.                                   0.054469
# set force change user password.                0.012969
# Name: proportion, dtype: float64
#
# Category percentages for column EntityType before replacement:
# EntityType
# Ip                       22.918358
# User                     20.311854
# MailMessage              12.326396
# Machine                   7.337706
# File                      7.231672
# Url                       7.176271
# CloudLogonRequest         6.706013
# Mailbox                   5.080554
# Process                   3.636094
# MailCluster               2.359666
# CloudApplication          2.278636
# CloudLogonSession         2.230518
# RegistryValue             0.117599
# AzureResource             0.086119
# RegistryKey               0.076428
# GenericEntity             0.046290
# OAuthApplication          0.027716
# Malware                   0.026558
# SecurityGroup             0.015511
# BlobContainer             0.003245
# Blob                      0.003093
# MailboxConfiguration      0.002377
# Nic                       0.000594
# IoTDevice                 0.000305
# ActiveDirectoryDomain     0.000107
# GoogleCloudResource       0.000091
# AmazonResource            0.000076
# Container                 0.000030
# KubernetesCluster         0.000030
# ContainerImage            0.000030
# KubernetesNamespace       0.000030
# KubernetesPod             0.000015
# ContainerRegistry         0.000015
# Name: proportion, dtype: float64
#
# Category percentages for column EvidenceRole before replacement:
# EvidenceRole
# Related     54.725876
# Impacted    45.274124
# Name: proportion, dtype: float64
#
# Category percentages for column EmailClusterId before replacement:
# EmailClusterId
# 4218786605.0    2.055523
# 4023349548.0    1.991101
# 4140628171.0    1.802328
# 1962111205.0    0.885433
# 2122467325.0    0.603772
#                   ...
# 3220551788.0    0.001498
# 3220598823.0    0.001498
# 3220600367.0    0.001498
# 3220601383.0    0.001498
# 4294964916.0    0.001498
# Name: proportion, Length: 21175, dtype: float64
#
# Category percentages for column ApplicationName before replacement:
# ApplicationName
# 3421    97.695888
# 0        0.649657
# 1        0.403778
# 2        0.385357
# 3        0.333506
#           ...
# 1383     0.000015
# 1382     0.000015
# 1377     0.000015
# 1374     0.000015
# 1231     0.000015
# Name: proportion, Length: 2112, dtype: float64
#
# Category percentages for column ThreatFamily before replacement:
# ThreatFamily
# Phish                        4.756102
# Malgent                      3.522107
# Donoff                       3.402189
# CustomEnterpriseBlockOnly    2.868361
# CustomEnterpriseBlock        2.792929
#                                ...
# Adrepack                     0.001934
# SCPT                         0.001934
# Mikcer                       0.001934
# Acapaladat                   0.001934
# TiCeroe                      0.001934
# Name: proportion, Length: 1604, dtype: float64
#
# Category percentages for column ResourceType before replacement:
# ResourceType
# Virtual Machine                         58.426040
# Key Vault                                6.654306
# App Service                              5.974454
# Azure Arc machine                        5.191595
# Storage Account                          5.088587
# Subscription                             4.017305
# SQL Database                             3.172641
# Azure Database for MySQL Server          2.472188
# Azure Resource                           2.245571
# Virtual Machine Scale Set                1.565719
# API Management Service                   1.297899
# Key Vault Secret                         1.215492
# Azure Database for PostgreSQL Server     0.700453
# SQL Server                               0.556242
# Azure Cosmos DB Account                  0.432633
# Networking                               0.226617
# SQL Managed Instance                     0.144211
# Synapse SQL Pool                         0.123609
# GCP Compute Instance                     0.123609
# AWS EC2 Instance                         0.103008
# Kubernetes Service                       0.103008
# Key Vault Certificate                    0.082406
# Key Vault Key                            0.041203
# Cognitive Service                        0.020602
# Synapse Workspace                        0.020602
# Name: proportion, dtype: float64
#
# Category percentages for column Roles before replacement:
# Roles
# Contextual        59.825328
# Destination       15.695228
# Suspicious        13.290819
# Attacker           5.976409
# Source             3.337017
# Compromised        1.469139
# PolicyViolator     0.312200
# Attacked           0.091197
# Edited             0.002663
# Name: proportion, dtype: float64
#
# Category percentages for column OSFamily before replacement:
# OSFamily
# 5    97.963936
# 0     1.991831
# 1     0.028600
# 2     0.015526
# 3     0.000091
# 4     0.000015
# Name: proportion, dtype: float64
#
# Category percentages for column OSVersion before replacement:
# OSVersion
# 66    97.964012
# 0      1.964207
# 2      0.019671
# 1      0.017294
# 3      0.011550
# 4      0.007710
# 6      0.004099
# 5      0.002865
# 8      0.001371
# 9      0.001158
# 7      0.000899
# 10     0.000823
# 11     0.000762
# 12     0.000472
# 16     0.000366
# 14     0.000320
# 13     0.000320
# 15     0.000259
# 17     0.000213
# 19     0.000198
# 20     0.000198
# 21     0.000183
# 22     0.000168
# 24     0.000137
# 26     0.000091
# 31     0.000076
# 25     0.000061
# 27     0.000046
# 29     0.000030
# 38     0.000030
# 30     0.000030
# 41     0.000030
# 28     0.000030
# 34     0.000030
# 35     0.000015
# 48     0.000015
# 64     0.000015
# 63     0.000015
# 62     0.000015
# 58     0.000015
# 56     0.000015
# 52     0.000015
# 51     0.000015
# 47     0.000015
# 36     0.000015
# 46     0.000015
# 45     0.000015
# 23     0.000015
# 42     0.000015
# 33     0.000015
# 40     0.000015
# 37     0.000015
# 43     0.000015
# Name: proportion, dtype: float64
#
# Category percentages for column AntispamDirection before replacement:
# AntispamDirection
# Inbound                                               90.894193
# Intraorg                                               8.627287
# Outbound                                               0.469507
# DomainPII_50d8b4a941c26b89482c94ab324b5a274f9ced66     0.004916
# DomainPII_df80ab894e01e375bf55d12ba315c04029d3e32d     0.004097
# Name: proportion, dtype: float64
#
# Category percentages for column SuspicionLevel before replacement:
# SuspicionLevel
# Suspicious      99.896838
# Incriminated     0.103162
# Name: proportion, dtype: float64
#
# Category percentages for column LastVerdict before replacement:
# LastVerdict
# Suspicious                                            62.782779
# Malicious                                             19.421215
# NoThreatsFound                                        17.787632
# DomainPII_50d8b4a941c26b89482c94ab324b5a274f9ced66     0.005454
# DomainPII_9207384283ce115db5a590dd9ca5de21e5e99df2     0.002922
# Name: proportion, dtype: float64
#
# Category percentages for column CountryCode before replacement:
# CountryCode
# 242.0    92.122357
# 0.0       1.819441
# 1.0       1.122047
# 2.0       0.566951
# 4.0       0.422703
#            ...
# 199.0     0.000015
# 184.0     0.000015
# 186.0     0.000015
# 188.0     0.000015
# 177.0     0.000015
# Name: proportion, Length: 230, dtype: float64
#
# Category percentages for column State before replacement:
# State
# 1445.0    93.347437
# 0.0        1.095306
# 1.0        0.422870
# 2.0        0.305196
# 3.0        0.242831
#             ...
# 1145.0     0.000015
# 1146.0     0.000015
# 1147.0     0.000015
# 1148.0     0.000015
# 929.0      0.000015
# Name: proportion, Length: 1270, dtype: float64
#
# Category percentages for column City before replacement:
# City
# 10630.0    93.340763
# 0.0         1.090827
# 1.0         0.233491
# 2.0         0.205988
# 3.0         0.167042
#              ...
# 6058.0      0.000015
# 6059.0      0.000015
# 6064.0      0.000015
# 6067.0      0.000015
# 5647.0      0.000015
# Name: proportion, Length: 8141, dtype: float64
#
# Category percentages for column OrgId after replacement:
# OrgId
# Others    64.647063
# 0          8.884147
# 2          2.533032
# 1          2.210253
# 3          2.005392
# 5          1.820203
# 6          1.694239
# 4          1.529574
# 7          1.413773
# 8          1.407983
# 10         1.399237
# 9          1.377311
# 11         1.224332
# 12         1.205317
# 14         1.186636
# 13         1.125353
# 16         0.926085
# 25         0.883147
# 17         0.854807
# 19         0.843181
# 18         0.828934
# Name: proportion, dtype: float64
#
# Category percentages for column Timestamp after replacement:
# Timestamp
# 2024-06-12T01:27:49.000Z    0.118802
# 2024-06-11T16:33:15.000Z    0.028295
# 2024-06-03T11:48:56.000Z    0.025156
# 2024-06-07T22:16:14.000Z    0.015709
# 2024-06-09T23:29:15.000Z    0.015709
#                               ...
# 2024-06-11T12:12:23.000Z    0.000015
# 2024-06-17T01:34:46.000Z    0.000015
# 2024-06-08T09:07:06.000Z    0.000015
# 2024-06-06T17:12:49.000Z    0.000015
# 2024-05-22T15:27:12.000Z    0.000015
# Name: proportion, Length: 749546, dtype: float64
#
# Category percentages for column DetectorId after replacement:
# DetectorId
# Others    37.877497
# 0         14.001284
# 1          8.137934
# 2          6.270816
# 3          5.162833
# 4          4.331263
# 5          3.593781
# 6          3.513650
# 7          3.248070
# 9          1.618542
# 8          1.527623
# 10         1.426328
# 12         1.376031
# 11         1.236994
# 15         1.017720
# 17         0.996022
# 16         0.983315
# 13         0.978683
# 18         0.953268
# 14         0.933658
# 19         0.814688
# Name: proportion, dtype: float64
#
# Category percentages for column AlertTitle after replacement:
# AlertTitle
# Others    43.680387
# 0         14.001284
# 1          8.137934
# 2          6.270816
# 4          4.353113
# 3          4.331263
# 5          3.513650
# 6          3.248070
# 7          1.527623
# 8          1.426328
# 9          1.236994
# 10         1.108440
# 13         1.019030
# 11         0.978683
# 14         0.956163
# 12         0.933658
# 15         0.814688
# 16         0.658007
# 17         0.630016
# 19         0.603077
# 20         0.570775
# Name: proportion, dtype: float64
#
# Category percentages for column Category after replacement:
# Category
# InitialAccess          45.105207
# Exfiltration           16.582343
# SuspiciousActivity     10.560330
# CommandAndControl       8.677229
# Impact                  7.896794
# CredentialAccess        3.154957
# Execution               2.812690
# Malware                 1.513956
# Discovery               1.355477
# Persistence             0.763690
# DefenseEvasion          0.489806
# LateralMovement         0.438107
# Ransomware              0.199314
# UnwantedSoftware        0.192884
# Collection              0.154792
# PrivilegeEscalation     0.050084
# Exploit                 0.047935
# CredentialStealing      0.003962
# WebExploit              0.000381
# Weaponization           0.000061
# Name: proportion, dtype: float64
#
# Category percentages for column MitreTechniques after replacement:
# MitreTechniques
# T1078;T1078.004                                    33.472637
# T1566.002                                          20.111426
# T1566                                              16.279672
# T1133                                               3.591781
# T1566.001                                           3.389954
#                                                      ...
# T1055;T1055.002;T1055.003;T1055.012;T1078;T1106     0.000036
# T0814                                               0.000036
# T1021.002;T1204;T1570                               0.000036
# T1484;T1484.001                                     0.000036
# T1068;T1548                                         0.000036
# Name: proportion, Length: 1182, dtype: float64
#
# Category percentages for column IncidentGrade after replacement:
# IncidentGrade
# BenignPositive    43.423853
# TruePositive      35.112871
# FalsePositive     21.463277
# Name: proportion, dtype: float64
#
# Category percentages for column ActionGrouped after replacement:
# ActionGrouped
# ContainAccount           95.839602
# IsolateDevice             4.030710
# Stop Virtual Machines     0.129688
# Name: proportion, dtype: float64
#
# Category percentages for column ActionGranular after replacement:
# ActionGranular
# update stsrefreshtokenvalidfrom timestamp.    38.366966
# account password changed                      25.156923
# change user password.                         24.075323
# isolateresponse                                3.659802
# account disabled                               3.491207
# disable account.                               2.043886
# reset user password.                           1.561446
# forcepasswordresetremediation                  0.383877
# quarantinefile                                 0.370908
# msecidentitiesconfirmusercompromised           0.241220
# disableuser                                    0.199720
# msecidentitiessuspenduser                      0.163407
# delete virtualmachines                         0.129688
# account deleted                                0.088188
# delete user.                                   0.054469
# set force change user password.                0.012969
# Name: proportion, dtype: float64
#
# Category percentages for column EntityType after replacement:
# EntityType
# Ip                       22.918358
# User                     20.311854
# MailMessage              12.326396
# Machine                   7.337706
# File                      7.231672
# Url                       7.176271
# CloudLogonRequest         6.706013
# Mailbox                   5.080554
# Process                   3.636094
# MailCluster               2.359666
# CloudApplication          2.278636
# CloudLogonSession         2.230518
# RegistryValue             0.117599
# AzureResource             0.086119
# RegistryKey               0.076428
# GenericEntity             0.046290
# OAuthApplication          0.027716
# Malware                   0.026558
# SecurityGroup             0.015511
# BlobContainer             0.003245
# Blob                      0.003093
# MailboxConfiguration      0.002377
# Nic                       0.000594
# IoTDevice                 0.000305
# ActiveDirectoryDomain     0.000107
# GoogleCloudResource       0.000091
# AmazonResource            0.000076
# Container                 0.000030
# KubernetesCluster         0.000030
# ContainerImage            0.000030
# KubernetesNamespace       0.000030
# KubernetesPod             0.000015
# ContainerRegistry         0.000015
# Name: proportion, dtype: float64
#
# Category percentages for column EvidenceRole after replacement:
# EvidenceRole
# Related     54.725876
# Impacted    45.274124
# Name: proportion, dtype: float64
#
# Category percentages for column EmailClusterId after replacement:
# EmailClusterId
# Others          86.700526
# 4218786605.0     2.055523
# 4023349548.0     1.991101
# 4140628171.0     1.802328
# 1962111205.0     0.885433
# 2122467325.0     0.603772
# 2834092745.0     0.602274
# 3425846815.0     0.551336
# 2763420209.0     0.509386
# 2681535163.0     0.491408
# 3370906157.0     0.461444
# 2900576879.0     0.450957
# 4143707853.0     0.406011
# 4107518491.0     0.386534
# 2901398217.0     0.359567
# 4274415102.0     0.301137
# 3423486872.0     0.299639
# 2136032619.0     0.290650
# 4264033966.0     0.284657
# 3155166229.0     0.283159
# 3326931161.0     0.283159
# Name: proportion, dtype: float64
#
# Category percentages for column ApplicationName after replacement:
# ApplicationName
# 3421      97.695888
# 0          0.649657
# 1          0.403778
# 2          0.385357
# 3          0.333506
# 4          0.236736
# Others     0.096236
# 5          0.069435
# 6          0.029986
# 7          0.027564
# 8          0.020905
# 9          0.010925
# 10         0.007253
# 12         0.006247
# 11         0.006156
# 13         0.005242
# 15         0.003901
# 14         0.003733
# 16         0.003032
# 17         0.002346
# 19         0.002118
# Name: proportion, dtype: float64
#
# Category percentages for column ThreatFamily after replacement:
# ThreatFamily
# Phish                        4.756102
# Malgent                      3.522107
# Donoff                       3.402189
# CustomEnterpriseBlockOnly    2.868361
# CustomEnterpriseBlock        2.792929
#                                ...
# Adrepack                     0.001934
# SCPT                         0.001934
# Mikcer                       0.001934
# Acapaladat                   0.001934
# TiCeroe                      0.001934
# Name: proportion, Length: 1604, dtype: float64
#
# Category percentages for column ResourceType after replacement:
# ResourceType
# Virtual Machine                         58.426040
# Key Vault                                6.654306
# App Service                              5.974454
# Azure Arc machine                        5.191595
# Storage Account                          5.088587
# Subscription                             4.017305
# SQL Database                             3.172641
# Azure Database for MySQL Server          2.472188
# Azure Resource                           2.245571
# Virtual Machine Scale Set                1.565719
# API Management Service                   1.297899
# Key Vault Secret                         1.215492
# Azure Database for PostgreSQL Server     0.700453
# SQL Server                               0.556242
# Azure Cosmos DB Account                  0.432633
# Networking                               0.226617
# SQL Managed Instance                     0.144211
# Synapse SQL Pool                         0.123609
# GCP Compute Instance                     0.123609
# AWS EC2 Instance                         0.103008
# Kubernetes Service                       0.103008
# Key Vault Certificate                    0.082406
# Key Vault Key                            0.041203
# Cognitive Service                        0.020602
# Synapse Workspace                        0.020602
# Name: proportion, dtype: float64
#
# Category percentages for column Roles after replacement:
# Roles
# Contextual        59.825328
# Destination       15.695228
# Suspicious        13.290819
# Attacker           5.976409
# Source             3.337017
# Compromised        1.469139
# PolicyViolator     0.312200
# Attacked           0.091197
# Edited             0.002663
# Name: proportion, dtype: float64
#
# Category percentages for column OSFamily after replacement:
# OSFamily
# 5    97.963936
# 0     1.991831
# 1     0.028600
# 2     0.015526
# 3     0.000091
# 4     0.000015
# Name: proportion, dtype: float64
#
# Category percentages for column OSVersion after replacement:
# OSVersion
# 66        97.964012
# 0          1.964207
# 2          0.019671
# 1          0.017294
# 3          0.011550
# 4          0.007710
# 6          0.004099
# 5          0.002865
# Others     0.001432
# 8          0.001371
# 9          0.001158
# 7          0.000899
# 10         0.000823
# 11         0.000762
# 12         0.000472
# 16         0.000366
# 13         0.000320
# 14         0.000320
# 15         0.000259
# 17         0.000213
# 19         0.000198
# Name: proportion, dtype: float64
#
# Category percentages for column AntispamDirection after replacement:
# AntispamDirection
# Inbound                                               90.894193
# Intraorg                                               8.627287
# Outbound                                               0.469507
# DomainPII_50d8b4a941c26b89482c94ab324b5a274f9ced66     0.004916
# DomainPII_df80ab894e01e375bf55d12ba315c04029d3e32d     0.004097
# Name: proportion, dtype: float64
#
# Category percentages for column SuspicionLevel after replacement:
# SuspicionLevel
# Suspicious      99.896838
# Incriminated     0.103162
# Name: proportion, dtype: float64
#
# Category percentages for column LastVerdict after replacement:
# LastVerdict
# Suspicious                                            62.782779
# Malicious                                             19.421215
# NoThreatsFound                                        17.787632
# DomainPII_50d8b4a941c26b89482c94ab324b5a274f9ced66     0.005454
# DomainPII_9207384283ce115db5a590dd9ca5de21e5e99df2     0.002922
# Name: proportion, dtype: float64
#
# Category percentages for column CountryCode after replacement:
# CountryCode
# 242.0     92.122357
# 0.0        1.819441
# Others     1.247965
# 1.0        1.122047
# 2.0        0.566951
# 4.0        0.422703
# 3.0        0.381685
# 5.0        0.350937
# 6.0        0.240180
# 7.0        0.203443
# 8.0        0.187490
# 9.0        0.175529
# 10.0       0.166509
# 12.0       0.155645
# 11.0       0.147128
# 14.0       0.141094
# 13.0       0.140698
# 15.0       0.121210
# 17.0       0.099726
# 16.0       0.094987
# 18.0       0.092275
# Name: proportion, dtype: float64
#
# Category percentages for column State after replacement:
# State
# 1445.0    93.347437
# Others     2.755171
# 0.0        1.095306
# 1.0        0.422870
# 2.0        0.305196
# 3.0        0.242831
# 4.0        0.200335
# 5.0        0.165808
# 6.0        0.163782
# 7.0        0.152156
# 8.0        0.131281
# 9.0        0.128005
# 11.0       0.125903
# 12.0       0.120814
# 10.0       0.120082
# 13.0       0.103215
# 15.0       0.097973
# 14.0       0.097105
# 21.0       0.077175
# 17.0       0.075042
# 16.0       0.072513
# Name: proportion, dtype: float64
#
# Category percentages for column City after replacement:
# City
# 10630.0    93.340763
# Others      3.409597
# 0.0         1.090827
# 1.0         0.233491
# 2.0         0.205988
# 3.0         0.167042
# 4.0         0.151790
# 5.0         0.145665
# 6.0         0.126345
# 7.0         0.120036
# 8.0         0.113561
# 9.0         0.110605
# 12.0        0.103002
# 10.0        0.102773
# 11.0        0.097105
# 13.0        0.092823
# 14.0        0.084717
# 15.0        0.077739
# 16.0        0.076550
# 23.0        0.075819
# 18.0        0.073762
# Name: proportion, dtype: float64
#
# Data types of each column after conversion:
# OrgId                category
# Timestamp              object
# DetectorId           category
# AlertTitle           category
# Category               object
# MitreTechniques        object
# IncidentGrade          object
# ActionGrouped          object
# ActionGranular         object
# EntityType             object
# EvidenceRole           object
# EmailClusterId       category
# ApplicationName      category
# ThreatFamily           object
# ResourceType           object
# Roles                  object
# OSFamily             category
# OSVersion            category
# AntispamDirection      object
# SuspicionLevel         object
# LastVerdict            object
# CountryCode          category
# State                category
# City                 category
# dtype: object

# %%
import pandas as pd
import numpy as np

def preprocess_data(input_file_path, output_file_path, missing_threshold=0.5):
    try:
        # Load the DataFrame
        df = pd.read_csv(input_file_path)
        print(f"Loaded data with {df.shape[0]} rows and {df.shape[1]} columns.")

        # Drop columns with high missing values
        missing_percentages = df.isnull().mean()
        columns_to_drop = missing_percentages[missing_percentages > missing_threshold].index
        df.drop(columns=columns_to_drop, inplace=True)
        print(f"Columns dropped due to more than {missing_threshold * 100}% missing values: {columns_to_drop.tolist()}")

        # Remove duplicates
        df.drop_duplicates(inplace=True)
        print(f"Duplicates removed. Number of rows after deduplication: {df.shape[0]}")

        # Feature extraction from 'Timestamp'
        if 'Timestamp' in df.columns:
            df['Timestamp'] = pd.to_datetime(df['Timestamp'], errors='coerce')
            df['Year'] = df['Timestamp'].dt.year
            df['Month'] = df['Timestamp'].dt.month
            df['DayOfWeek'] = df['Timestamp'].dt.dayofweek
            df['Hour'] = df['Timestamp'].dt.hour
            df.drop(columns=['Timestamp'], inplace=True)
            print("Timestamp features extracted.")

        # Fill missing values in specific columns with their mode
        for column in ['CountryCode', 'State', 'City']:
            if column in df.columns:
                mode_value = df[column].mode()[0]
                df[column].fillna(mode_value, inplace=True)
                print(f"Filled missing values in '{column}' with mode: {mode_value}")

        # Fill missing values in 'IncidentGrade' equally
        if 'IncidentGrade' in df.columns:
            # Calculate and print the original value counts
            original_value_counts = df['IncidentGrade'].value_counts()
            print("Original value counts before filling missing values:")
            print(original_value_counts)

            # Identify unique values in the IncidentGrade column
            unique_values = df['IncidentGrade'].dropna().unique()

            # Count the number of missing values
            num_missing = df['IncidentGrade'].isnull().sum()

            # Create a list of values to fill the missing values equally
            fill_values = []
            for value in unique_values:
                fill_values.extend([value] * (num_missing // len(unique_values)))

            # If there are any remaining missing values, distribute them
            remaining = num_missing % len(unique_values)
            fill_values.extend(np.random.choice(unique_values, remaining))

            # Shuffle the fill_values list to randomize the distribution
            np.random.shuffle(fill_values)

            # Fill the missing values with the prepared list
            df.loc[df['IncidentGrade'].isnull(), 'IncidentGrade'] = fill_values

            # Calculate and print the value counts after filling the missing values
            filled_value_counts = df['IncidentGrade'].value_counts()
            print("\nValue counts after filling missing values:")
            print(filled_value_counts)

        # Convert all columns to 'category' dtype
        df = df.astype('category')

        # Save the preprocessed DataFrame
        df.to_csv(output_file_path, index=False)
        print(f"Preprocessed data saved to {output_file_path}.")

    except Exception as e:
        print(f"An error occurred: {e}")

# Define file paths
input_file_path = r"C:\Users\Elakkiya\Downloads\microsoft cybersecurity\GUIDE_Train.csv"
output_file_path = r"C:\Users\Elakkiya\Downloads\microsoft cybersecurity\preprocessed_data_1.csv"

# Run the preprocessing function
preprocess_data(input_file_path, output_file_path)
# Out:
# Loaded data with 6563005 rows and 45 columns.
# Columns dropped due to more than 50.0% missing values: ['MitreTechniques', 'ActionGrouped', 'ActionGranular', 'EmailClusterId', 'ThreatFamily', 'ResourceType', 'Roles', 'AntispamDirection', 'SuspicionLevel', 'LastVerdict']
# Duplicates removed. Number of rows after deduplication: 6279876
# Timestamp features extracted.
# Filled missing values in 'CountryCode' with mode: 242.0
# Filled missing values in 'State' with mode: 1445.0
# Filled missing values in 'City' with mode: 10630.0
# Original value counts before filling missing values:
# IncidentGrade
# BenignPositive    2688137
# TruePositive      2196547
# FalsePositive     1361518
# Name: count, dtype: int64
#
# Value counts after filling missing values:
# IncidentGrade
# BenignPositive    2699362
# TruePositive      2207771
# FalsePositive     1372743
# Name: count, dtype: int64

# %%
import pandas as pd

# Define file paths
input_file_path = r"C:\Users\Elakkiya\Downloads\microsoft cybersecurity\preprocessed_data_1.csv"
output_file_path = r"C:\Users\Elakkiya\Downloads\microsoft cybersecurity\top_n_categories_1.csv"
top_n_categories = 5  # Number of top categories to retain

# Read the CSV file
try:
    df = pd.read_csv(input_file_path)
except FileNotFoundError:
    print(f"Error: The file at {input_file_path} was not found.")
    raise
except pd.errors.EmptyDataError:
    print("Error: The file is empty.")
    raise

# Display initial columns to verify the read operation
print("Initial columns in the DataFrame:")
print(df.columns.tolist())

# Columns to be dropped
columns_to_drop = [
    'Id', 'IncidentId', 'AlertId', 'DeviceId', 'Sha256', 'IpAddress', 'Url',
    'AccountSid', 'AccountUpn', 'AccountObjectId', 'AccountName', 'DeviceName',
    'NetworkMessageId', 'RegistryKey', 'RegistryValueName', 'RegistryValueData',
    'ApplicationId', 'OAuthApplicationId', 'FileName', 'FolderPath', 'ResourceIdName'
]

# Check if the columns to drop are in the DataFrame
columns_to_drop = [col for col in columns_to_drop if col in df.columns]

# Removing specified columns
df = df.drop(columns=columns_to_drop)

# Display columns after dropping to verify the drop operation
print("Columns after dropping:")
print(df.columns.tolist())

# Convert all columns to 'category' dtype
df = df.astype('category')

# Replace rare categories with 'Other'
def replace_rare_categories(df, top_n=5, replace_name='other'):
    for col in df.select_dtypes(include=['category']).columns:
        top_categories = df[col].value_counts().nlargest(top_n).index
        df[col] = df[col].apply(lambda x: x if x in top_categories else replace_name)
        df[col] = df[col].astype('category')

replace_rare_categories(df, top_n=top_n_categories)

# Save the preprocessed DataFrame
try:
    df.to_csv(output_file_path, index=False)
    print(f"Processed data saved to {output_file_path}.")
except Exception as e:
    print(f"Error saving file: {e}")
    raise

# Display the processed DataFrame
print("\nProcessed DataFrame:")
print(df.head())
print(f"Shape of processed DataFrame: {df.shape}")

# Check for missing values
print("\nMissing values:")
print(df.isnull().sum())

# Display data types of each column
print("\nData types of each column:")
print(df.dtypes)

# Display the number of unique categories for each column
print("\nNumber of unique categories per column:")
for col in df.select_dtypes(include=['category']).columns:
    num_unique_categories = df[col].nunique()
    print(f"{col}: {num_unique_categories}")

# Optionally, display the number of unique values for non-categorical columns
print("\nNumber of unique values per non-categorical column:")
for col in df.select_dtypes(exclude=['category']).columns:
    num_unique_values = df[col].nunique()
    print(f"{col}: {num_unique_values}")
# Out:
# Initial columns in the DataFrame:
# ['Id', 'OrgId', 'IncidentId', 'AlertId', 'DetectorId', 'AlertTitle', 'Category', 'IncidentGrade', 'EntityType', 'EvidenceRole', 'DeviceId', 'Sha256', 'IpAddress', 'Url', 'AccountSid', 'AccountUpn', 'AccountObjectId', 'AccountName', 'DeviceName', 'NetworkMessageId', 'RegistryKey', 'RegistryValueName', 'RegistryValueData', 'ApplicationId', 'ApplicationName', 'OAuthApplicationId', 'FileName', 'FolderPath', 'ResourceIdName', 'OSFamily', 'OSVersion', 'CountryCode', 'State', 'City', 'Year', 'Month', 'DayOfWeek', 'Hour']
# Columns after dropping:
# ['OrgId', 'DetectorId', 'AlertTitle', 'Category', 'IncidentGrade', 'EntityType', 'EvidenceRole', 'ApplicationName', 'OSFamily', 'OSVersion', 'CountryCode', 'State', 'City', 'Year', 'Month', 'DayOfWeek', 'Hour']
# Processed data saved to C:\Users\Elakkiya\Downloads\microsoft cybersecurity\top_n_categories_1.csv.
#
# Processed DataFrame:
#    OrgId DetectorId AlertTitle           Category   IncidentGrade EntityType  \
# 0      0      other      other      InitialAccess    TruePositive         Ip
# 1  other      other      other       Exfiltration   FalsePositive       User
# 2  other      other      other      InitialAccess   FalsePositive      other
# 3  other          2          2  CommandAndControl  BenignPositive      other
# 4  other      other      other              other    TruePositive       User
#
#   EvidenceRole ApplicationName OSFamily OSVersion CountryCode   State  \
# 0      Related            3421        5        66       other   other
# 1     Impacted            3421        5        66       242.0  1445.0
# 2      Related            3421        5        66       242.0  1445.0
# 3      Related            3421        5        66       242.0  1445.0
# 4     Impacted            3421        5        66       242.0  1445.0
#
#       City  Year Month DayOfWeek   Hour
# 0      3.0  2024     6         1  other
# 1  10630.0  2024     6         4  other
# 2  10630.0  2024     6         3  other
# 3  10630.0  2024     6         0     16
# 4  10630.0  2024     6     other  other
# Shape of processed DataFrame: (3951714, 17)
#
# Missing values:
# OrgId              0
# DetectorId         0
# AlertTitle         0
# Category           0
# IncidentGrade      0
# EntityType         0
# EvidenceRole       0
# ApplicationName    0
# OSFamily           0
# OSVersion          0
# CountryCode        0
# State              0
# City               0
# Year               0
# Month              0
# DayOfWeek          0
# Hour               0
# dtype: int64
#
# Data types of each column:
# OrgId              category
# DetectorId         category
# AlertTitle         category
# Category           category
# IncidentGrade      category
# EntityType         category
# EvidenceRole       category
# ApplicationName    category
# OSFamily           category
# OSVersion          category
# CountryCode        category
# State              category
# City               category
# Year               category
# Month              category
# DayOfWeek          category
# Hour               category
# dtype: object
#
# Number of unique categories per column:
# OrgId: 6
# DetectorId: 6
# AlertTitle: 6
# Category: 6
# IncidentGrade: 3
# EntityType: 6
# EvidenceRole: 2
# ApplicationName: 6
# OSFamily: 6
# OSVersion: 6
# CountryCode: 6
# State: 6
# City: 6
# Year: 2
# Month: 6
# DayOfWeek: 6
# Hour: 6
#
# Number of unique values per non-categorical column:

# %%
import pandas as pd

# Read the CSV file
file_path = r"C:\Users\Elakkiya\Downloads\microsoft cybersecurity\top_n_categories_1.csv"
df = pd.read_csv(file_path)

# Display initial DataFrame
print("Initial DataFrame:")
print(df.head())

# Print the rows before removing outliers
print("\nRows before removing outliers:")
print(df)

# Function to identify and remove outliers
def identify_and_remove_outliers(df):
    outlier_indices = []
    for col in df.select_dtypes(include=[float, int]).columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
        outlier_indices.extend(outliers.index.tolist())
    
    outlier_indices = list(set(outlier_indices))
    outlier_rows = df.loc[outlier_indices]
    df_cleaned = df.drop(outlier_indices)
    
    return df_cleaned, outlier_rows

# Identify and remove outliers
df_cleaned, outlier_rows = identify_and_remove_outliers(df)

# Print the rows identified as outliers
print("\nRows identified as outliers:")
print(outlier_rows)

# Print the cleaned DataFrame
print("\nCleaned DataFrame:")
print(df_cleaned.head())

# Print the rows after removing outliers
print("\nRows after removing outliers:")
print(df_cleaned)

# Save the cleaned DataFrame to a new CSV file
output_file_path = r"C:\Users\Elakkiya\Downloads\microsoft cybersecurity\top_n_categories_cleaned_1.csv"
df_cleaned.to_csv(output_file_path, index=False)
print(f"\nCleaned data saved to {output_file_path}")
# Out:
# C:\Users\Elakkiya\AppData\Local\Temp\ipykernel_11480\1039603835.py:5: DtypeWarning: Columns (8,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# Initial DataFrame:
#    OrgId DetectorId AlertTitle           Category   IncidentGrade EntityType  \
# 0      0      other      other      InitialAccess    TruePositive         Ip
# 1  other      other      other       Exfiltration   FalsePositive       User
# 2  other      other      other      InitialAccess   FalsePositive      other
# 3  other          2          2  CommandAndControl  BenignPositive      other
# 4  other      other      other              other    TruePositive       User
#
#   EvidenceRole ApplicationName OSFamily OSVersion CountryCode   State  \
# 0      Related            3421        5        66       other   other
# 1     Impacted            3421        5        66       242.0  1445.0
# 2      Related            3421        5        66       242.0  1445.0
# 3      Related            3421        5        66       242.0  1445.0
# 4     Impacted            3421        5        66       242.0  1445.0
#
#       City  Year Month DayOfWeek   Hour
# 0      3.0  2024     6         1  other
# 1  10630.0  2024     6         4  other
# 2  10630.0  2024     6         3  other
# 3  10630.0  2024     6         0     16
# 4  10630.0  2024     6     other  other
#
# Rows before removing outliers:
#          OrgId DetectorId AlertTitle            Category   IncidentGrade  \
# 0            0      other      other       InitialAccess    TruePositive
# 1        other      other      other        Exfiltration   FalsePositive
# 2        other      other      other       InitialAccess   FalsePositive
# 3        other          2          2   CommandAndControl  BenignPositive
# 4        other      other      other               other    TruePositive
# ...        ...        ...        ...                 ...             ...
# 3951709  other          3          4  SuspiciousActivity  BenignPositive
# 3951710  other      other      other       InitialAccess  BenignPositive
# 3951711  other      other      other  SuspiciousActivity    TruePositive
# 3951712  other          0          0       InitialAccess   FalsePositive
# 3951713  other      other      other               other  BenignPositive
#
#           EntityType EvidenceRole ApplicationName OSFamily OSVersion  \
# 0                 Ip      Related            3421        5        66
# 1               User     Impacted            3421        5        66
# 2              other      Related            3421        5        66
# 3              other      Related            3421        5        66
# 4               User     Impacted            3421        5        66
# ...              ...          ...             ...      ...       ...
# 3951709           Ip      Related            3421        5        66
# 3951710  MailMessage      Related            3421        5        66
# 3951711        other     Impacted               0        5        66
# 3951712        other      Related            3421        5        66
# 3951713           Ip      Related            3421        5        66
#
#         CountryCode   State     City  Year Month DayOfWeek   Hour
# 0             other   other      3.0  2024     6         1  other
# 1             242.0  1445.0  10630.0  2024     6         4  other
# 2             242.0  1445.0  10630.0  2024     6         3  other
# 3             242.0  1445.0  10630.0  2024     6         0     16
# 4             242.0  1445.0  10630.0  2024     6     other  other
# ...             ...     ...      ...   ...   ...       ...    ...
# 3951709       242.0  1445.0  10630.0  2024     6         0  other
# 3951710       242.0  1445.0  10630.0  2024     6         0  other
# 3951711       242.0  1445.0  10630.0  2024     6         4  other
# 3951712       242.0  1445.0  10630.0  2024     6         1     15
# 3951713       242.0  1445.0  10630.0  2024     6         3     16
#
# [3951714 rows x 17 columns]
#
# Rows identified as outliers:
#          OrgId DetectorId AlertTitle       Category   IncidentGrade  \
# 3939584  other      other      other  InitialAccess  BenignPositive
# 762881   other          0          0  InitialAccess    TruePositive
# 123140   other      other      other  InitialAccess  BenignPositive
# 2608388  other          0          0  InitialAccess    TruePositive
# 622599   other          0          0  InitialAccess    TruePositive
# ...        ...        ...        ...            ...             ...
# 3424496  other          0          0  InitialAccess    TruePositive
# 2760818  other          4          3  InitialAccess    TruePositive
# 1699315  other          0          0  InitialAccess    TruePositive
# 2415612      5          0          0  InitialAccess    TruePositive
# 3700094  other      other      other  InitialAccess    TruePositive
#
#         EntityType EvidenceRole ApplicationName OSFamily OSVersion  \
# 3939584      other     Impacted            3421        5        66
# 762881       other      Related            3421        5        66
# 123140       other     Impacted            3421        5        66
# 2608388      other      Related            3421        5        66
# 622599       other      Related            3421        5        66
# ...            ...          ...             ...      ...       ...
# 3424496         Ip      Related            3421        5        66
# 2760818      other      Related            3421        5        66
# 1699315      other      Related            3421        5        66
# 2415612      other      Related            3421        5        66
# 3700094      other      Related            3421        5        66
#
#         CountryCode   State     City  Year  Month DayOfWeek   Hour
# 3939584       242.0  1445.0  10630.0  2023  other         3  other
# 762881        242.0  1445.0  10630.0  2023  other     other  other
# 123140        242.0  1445.0  10630.0  2023  other         4     18
# 2608388       242.0  1445.0  10630.0  2023  other         4     16
# 622599        242.0  1445.0  10630.0  2023  other         4     13
# ...             ...     ...      ...   ...    ...       ...    ...
# 3424496         0.0   other    other  2023  other         1  other
# 2760818       242.0  1445.0  10630.0  2023  other         2  other
# 1699315       242.0  1445.0  10630.0  2023  other         0     16
# 2415612       242.0  1445.0  10630.0  2023  other         4  other
# 3700094       242.0  1445.0  10630.0  2023  other         0     16
#
# [72 rows x 17 columns]
#
# Cleaned DataFrame:
#    OrgId DetectorId AlertTitle           Category   IncidentGrade EntityType  \
# 0      0      other      other      InitialAccess    TruePositive         Ip
# 1  other      other      other       Exfiltration   FalsePositive       User
# 2  other      other      other      InitialAccess   FalsePositive      other
# 3  other          2          2  CommandAndControl  BenignPositive      other
# 4  other      other      other              other    TruePositive       User
#
#   EvidenceRole ApplicationName OSFamily OSVersion CountryCode   State  \
# 0      Related            3421        5        66       other   other
# 1     Impacted            3421        5        66       242.0  1445.0
# 2      Related            3421        5        66       242.0  1445.0
# 3      Related            3421        5        66       242.0  1445.0
# 4     Impacted            3421        5        66       242.0  1445.0
#
#       City  Year Month DayOfWeek   Hour
# 0      3.0  2024     6         1  other
# 1  10630.0  2024     6         4  other
# 2  10630.0  2024     6         3  other
# 3  10630.0  2024     6         0     16
# 4  10630.0  2024     6     other  other
#
# Rows after removing outliers:
#          OrgId DetectorId AlertTitle            Category   IncidentGrade  \
# 0            0      other      other       InitialAccess    TruePositive
# 1        other      other      other        Exfiltration   FalsePositive
# 2        other      other      other       InitialAccess   FalsePositive
# 3        other          2          2   CommandAndControl  BenignPositive
# 4        other      other      other               other    TruePositive
# ...        ...        ...        ...                 ...             ...
# 3951709  other          3          4  SuspiciousActivity  BenignPositive
# 3951710  other      other      other       InitialAccess  BenignPositive
# 3951711  other      other      other  SuspiciousActivity    TruePositive
# 3951712  other          0          0       InitialAccess   FalsePositive
# 3951713  other      other      other               other  BenignPositive
#
#           EntityType EvidenceRole ApplicationName OSFamily OSVersion  \
# 0                 Ip      Related            3421        5        66
# 1               User     Impacted            3421        5        66
# 2              other      Related            3421        5        66
# 3              other      Related            3421        5        66
# 4               User     Impacted            3421        5        66
# ...              ...          ...             ...      ...       ...
# 3951709           Ip      Related            3421        5        66
# 3951710  MailMessage      Related            3421        5        66
# 3951711        other     Impacted               0        5        66
# 3951712        other      Related            3421        5        66
# 3951713           Ip      Related            3421        5        66
#
#         CountryCode   State     City  Year Month DayOfWeek   Hour
# 0             other   other      3.0  2024     6         1  other
# 1             242.0  1445.0  10630.0  2024     6         4  other
# 2             242.0  1445.0  10630.0  2024     6         3  other
# 3             242.0  1445.0  10630.0  2024     6         0     16
# 4             242.0  1445.0  10630.0  2024     6     other  other
# ...             ...     ...      ...   ...   ...       ...    ...
# 3951709       242.0  1445.0  10630.0  2024     6         0  other
# 3951710       242.0  1445.0  10630.0  2024     6         0  other
# 3951711       242.0  1445.0  10630.0  2024     6         4  other
# 3951712       242.0  1445.0  10630.0  2024     6         1     15
# 3951713       242.0  1445.0  10630.0  2024     6         3     16
#
# [3951642 rows x 17 columns]
#
# Cleaned data saved to C:\Users\Elakkiya\Downloads\microsoft cybersecurity\top_n_categories_cleaned_1.csv

# %%
import pandas as pd

# Define file paths
input_file_path =  r"C:\Users\Elakkiya\Downloads\microsoft cybersecurity\top_n_categories_cleaned_1.csv"
output_file_path = r"C:\Users\Elakkiya\Downloads\microsoft cybersecurity\top_n_categories_encoded_1.csv"

# Define the number of top categories to retain and the replacement value for others
top_n_categories = 5
replacement_value = 6

# Function to encode top categories and replace others
def encode_categories(df, top_n=5, replacement_val=6):
    # Convert all integer columns to categorical
    for col in df.select_dtypes(include=['int64', 'float64']).columns:
        df[col] = df[col].astype('category')
    
    # Apply the encoding to each categorical column
    for col in df.select_dtypes(include=['category', 'object']).columns:
        # Convert to category type if not already
        df[col] = df[col].astype('category')
        category_counts = df[col].value_counts()
        top_categories = list(category_counts.nlargest(top_n).index)
        
        # Add 'Other' to the list of categories if not already present
        if 'Other' not in top_categories:
            top_categories.append('Other')
        
        # Ensure all categories are strings for consistent sorting and mapping
        top_categories = [str(cat) for cat in top_categories]
        
        # Create a manual mapping for label encoding, ensuring continuous integers
        unique_categories = sorted(top_categories)
        if 'Other' in unique_categories:
            unique_categories.remove('Other')
            unique_categories.append('Other')
        
        # Create the manual mapping
        manual_mapping = {category: i for i, category in enumerate(unique_categories)}
        
        # Add 'Other' to the Categorical type
        df[col] = df[col].cat.add_categories(['Other'])
        
        # Replace categories not in top_n with 'Other'
        df[col] = df[col].apply(lambda x: str(x) if str(x) in top_categories else 'Other')
        
        # Apply manual label encoding
        df[col] = df[col].map(manual_mapping)
        
        # Fill NaN values with the replacement value
        df[col] = df[col].fillna(manual_mapping['Other']).astype(int)
    
    return df

# Process the CSV file in chunks
chunk_size = 500000  # Adjust the chunk size as needed
chunks = []

for chunk in pd.read_csv(input_file_path, chunksize=chunk_size, low_memory=False):
    chunk_encoded = encode_categories(chunk, top_n=top_n_categories, replacement_val=replacement_value)
    chunks.append(chunk_encoded)

# Concatenate all chunks
df_encoded = pd.concat(chunks, axis=0)

# Save the processed DataFrame with encoded categories
df_encoded.to_csv(output_file_path, index=False)

# Display the processed DataFrame
print("\nProcessed DataFrame with encoded categories:")
print(df_encoded.head())
print(f"Shape of processed DataFrame: {df_encoded.shape}")

# Display the number of unique values per column after encoding
print("\nNumber of unique values per column after encoding:")
for col in df_encoded.columns:
    num_unique_values = df_encoded[col].nunique()
    print(f"{col}: {num_unique_values}")

# Check unique values in 'IncidentGrade'
unique_values = df_encoded['IncidentGrade'].unique()
print("\nUnique values in 'IncidentGrade':")
print(unique_values)
# Out:
# Processed DataFrame with encoded categories:
#    OrgId  DetectorId  AlertTitle  Category  IncidentGrade  EntityType  \
# 0      0           4           4         2              2           0
# 1      4           4           4         1              1           3
# 2      4           4           4         2              1           4
# 3      4           2           2         0              0           4
# 4      4           4           4         4              2           3
#
#    EvidenceRole  ApplicationName  OSFamily  OSVersion  CountryCode  State  \
# 0             1                3         3          3            4      4
# 1             0                3         3          3            3      2
# 2             1                3         3          3            3      2
# 3             1                3         3          3            3      2
# 4             0                3         3          3            3      2
#
#    City  Year  Month  DayOfWeek  Hour
# 0     5     0      3          1     4
# 1     2     0      3          5     4
# 2     2     0      3          3     4
# 3     2     0      3          0     1
# 4     2     0      3          4     4
# Shape of processed DataFrame: (3951642, 17)
#
# Number of unique values per column after encoding:
# OrgId: 6
# DetectorId: 6
# AlertTitle: 6
# Category: 6
# IncidentGrade: 3
# EntityType: 6
# EvidenceRole: 2
# ApplicationName: 6
# OSFamily: 5
# OSVersion: 6
# CountryCode: 6
# State: 6
# City: 6
# Year: 1
# Month: 6
# DayOfWeek: 6
# Hour: 6
#
# Unique values in 'IncidentGrade':
# [2 1 0]

# %%
import pandas as pd
from sklearn.feature_selection import SelectKBest, chi2

# Read the CSV file
file_path = r"C:\Users\Elakkiya\Downloads\microsoft cybersecurity\top_n_categories_encoded_1.csv"
df = pd.read_csv(file_path)

# Define the features (X) and the target (y)
X = df.drop(columns=['IncidentGrade'])
y = df['IncidentGrade']

# Perform Chi-Square test
chi2_selector = SelectKBest(chi2, k='all')
chi2_selector.fit(X, y)

# Create DataFrame to view scores and p-values
chi2_scores = pd.DataFrame({
    'Feature': X.columns,
    'Chi2 Score': chi2_selector.scores_,
    'P-value': chi2_selector.pvalues_
})

# Sort by Chi2 Score
chi2_scores = chi2_scores.sort_values(by='Chi2 Score', ascending=False)

# Print Chi2 Scores and P-values
print(chi2_scores)

# Select features based on Chi-Square p-values
selected_features_chi = chi2_scores[chi2_scores['P-value'] < 0.05]['Feature'].tolist()
print("Selected Features:", selected_features_chi)

# Create a DataFrame with the selected features and include the target variable
df_selected_features = df[selected_features_chi + ['IncidentGrade']]

# Save the selected features to a new CSV file
output_file_path = r"C:\Users\Elakkiya\Downloads\microsoft cybersecurity\selected_features_training_1.csv"
df_selected_features.to_csv(output_file_path, index=False)
print(f"Selected features saved to {output_file_path}")
# Out:
#             Feature     Chi2 Score        P-value
# 0             OrgId  297955.758813   0.000000e+00
# 2        AlertTitle  263826.742292   0.000000e+00
# 1        DetectorId  203297.829600   0.000000e+00
# 5      EvidenceRole   49468.547747   0.000000e+00
# 3          Category   25259.522824   0.000000e+00
# 4        EntityType   21362.178913   0.000000e+00
# 11             City   10060.360629   0.000000e+00
# 10            State    8762.995354   0.000000e+00
# 15             Hour    1591.941860   0.000000e+00
# 7          OSFamily    1181.583787  2.644482e-257
# 8         OSVersion    1039.734266  1.677154e-226
# 9       CountryCode     937.455311  2.717476e-204
# 13            Month     646.555607  4.001601e-141
# 6   ApplicationName     119.359514   1.206177e-26
# 14        DayOfWeek      49.352805   1.919440e-11
# 12             Year            NaN            NaN
# Selected Features: ['OrgId', 'AlertTitle', 'DetectorId', 'EvidenceRole', 'Category', 'EntityType', 'City', 'State', 'Hour', 'OSFamily', 'OSVersion', 'CountryCode', 'Month', 'ApplicationName', 'DayOfWeek']
# Selected features saved to C:\Users\Elakkiya\Downloads\microsoft cybersecurity\selected_features_training_1.csv

# %%
import pandas as pd
import numpy as np

# Define functions
def drop_usage_column(df):
    if 'Usage' in df.columns:
        df.drop(columns=['Usage'], inplace=True)
        print("Dropped 'Usage' column.")
    else:
        print("'Usage' column not found in the dataset.")
    return df

def drop_high_missing_values(df, threshold=0.5):
    missing_percentages = df.isnull().mean()
    columns_to_drop = missing_percentages[missing_percentages > threshold].index
    df.drop(columns=columns_to_drop, inplace=True)
    print(f"Columns dropped due to more than {threshold * 100}% missing values: {columns_to_drop.tolist()}")
    return df

def remove_duplicates(df):
    df.drop_duplicates(inplace=True)
    print(f"Duplicates removed. Number of rows after deduplication: {df.shape[0]}")
    return df

def extract_features(df):
    if 'Timestamp' in df.columns:
        df['Timestamp'] = pd.to_datetime(df['Timestamp'], errors='coerce')
        df['Year'] = df['Timestamp'].dt.year
        df['Month'] = df['Timestamp'].dt.month
        df['DayOfWeek'] = df['Timestamp'].dt.dayofweek
        df['Hour'] = df['Timestamp'].dt.hour
        df.drop(columns=['Timestamp'], inplace=True)
        print("Timestamp features extracted.")
    return df

def convert_to_category(df):
    return df.astype('category')

def replace_rare_categories(df, top_n=5, replace_name='other'):
    for col in df.select_dtypes(include=['category']).columns:
        top_categories = df[col].value_counts().nlargest(top_n).index
        df[col] = df[col].apply(lambda x: x if x in top_categories else replace_name)
        df[col] = df[col].astype('category')
    print(f"Replaced rare categories in each column with '{replace_name}'.")

def identify_and_remove_outliers(df):
    outlier_indices = []
    for col in df.select_dtypes(include=[float, int]).columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
        outlier_indices.extend(outliers.index.tolist())
    
    outlier_indices = list(set(outlier_indices))
    outlier_rows = df.loc[outlier_indices]
    df_cleaned = df.drop(outlier_indices)
    
    return df_cleaned, outlier_rows

# Load data
file_path = r"C:\Users\Elakkiya\Downloads\microsoft cybersecurity\GUIDE_Test.csv"
try:
    df = pd.read_csv(file_path)
    print(f"Loaded data with {df.shape[0]} rows and {df.shape[1]} columns.")
except FileNotFoundError:
    print(f"Error: The file at {file_path} was not found.")
    raise
except pd.errors.EmptyDataError:
    print("Error: The file is empty.")
    raise

# Step 1: Drop 'Usage' column
df = drop_usage_column(df)

# Step 2: Drop columns with high missing values
df = drop_high_missing_values(df)

# Step 3: Remove duplicate rows
df = remove_duplicates(df)

# Step 4: Extract features from 'Timestamp' column
df = extract_features(df)

# Step 5: Drop specified columns
columns_to_drop = [
    'Id', 'IncidentId', 'AlertId', 'DeviceId', 'Sha256', 'IpAddress', 'Url',
    'AccountSid', 'AccountUpn', 'AccountObjectId', 'AccountName', 'DeviceName',
    'NetworkMessageId', 'RegistryKey', 'RegistryValueName', 'RegistryValueData',
    'ApplicationId', 'OAuthApplicationId', 'FileName', 'FolderPath', 'ResourceIdName'
]
df.drop(columns=columns_to_drop, inplace=True, errors='ignore')
print(f"Dropped columns: {columns_to_drop}")

# Step 6: Convert all columns to 'category' dtype
df = convert_to_category(df)
print("Converted all columns to 'category' dtype.")

# Step 7: Replace rare categories
top_n_categories = 5  # Adjust the number of top categories as needed
replace_rare_categories(df, top_n=top_n_categories)

# Step 8: Identify and remove outliers
# Print the DataFrame before removing outliers
print("\nDataFrame before removing outliers:")
print(df.head())

df_cleaned, outlier_rows = identify_and_remove_outliers(df)

# Step 9: Print the rows identified as outliers
print("\nRows identified as outliers:")
print(outlier_rows)

# Print the DataFrame after removing outliers
print("\nDataFrame after removing outliers:")
print(df_cleaned.head())

# Step 10: Save the cleaned DataFrame to a new CSV file
output_file_path = r"C:\Users\Elakkiya\Downloads\microsoft cybersecurity\top_n_categories_cleaned_testing_1.csv"
df_cleaned.to_csv(output_file_path, index=False)
print(f"\nCleaned data saved to {output_file_path}")
# Out:
# C:\Users\Elakkiya\AppData\Local\Temp\ipykernel_11480\2782793322.py:66: DtypeWarning: Columns (10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# Loaded data with 4147992 rows and 46 columns.
# Dropped 'Usage' column.
# Columns dropped due to more than 50.0% missing values: ['MitreTechniques', 'ActionGrouped', 'ActionGranular', 'EmailClusterId', 'ThreatFamily', 'ResourceType', 'Roles', 'AntispamDirection', 'SuspicionLevel', 'LastVerdict']
# Duplicates removed. Number of rows after deduplication: 3922695
# Timestamp features extracted.
# Dropped columns: ['Id', 'IncidentId', 'AlertId', 'DeviceId', 'Sha256', 'IpAddress', 'Url', 'AccountSid', 'AccountUpn', 'AccountObjectId', 'AccountName', 'DeviceName', 'NetworkMessageId', 'RegistryKey', 'RegistryValueName', 'RegistryValueData', 'ApplicationId', 'OAuthApplicationId', 'FileName', 'FolderPath', 'ResourceIdName']
# Converted all columns to 'category' dtype.
# Replaced rare categories in each column with 'other'.
#
# DataFrame before removing outliers:
#    OrgId DetectorId AlertTitle           Category   IncidentGrade EntityType  \
# 0  other      other      other              other  BenignPositive       User
# 1      3          2          2  CommandAndControl  BenignPositive    Machine
# 2  other      other      other              other  BenignPositive      other
# 3  other          0          0      InitialAccess   FalsePositive      other
# 4  other      other      other              other  BenignPositive       User
#
#   EvidenceRole ApplicationName OSFamily OSVersion CountryCode State   City  \
# 0     Impacted            3421        5        66         242  1445  10630
# 1     Impacted            3421        0         0         242  1445  10630
# 2      Related            3421        5        66         242  1445  10630
# 3      Related            3421        5        66         242  1445  10630
# 4     Impacted            3421        5        66         242  1445  10630
#
#    Year Month DayOfWeek   Hour
# 0  2024     6         1  other
# 1  2024     6         0  other
# 2  2024     6     other  other
# 3  2024     6         2  other
# 4  2024     6         3     17
#
# Rows identified as outliers:
# Empty DataFrame
# Columns: [OrgId, DetectorId, AlertTitle, Category, IncidentGrade, EntityType, EvidenceRole, ApplicationName, OSFamily, OSVersion, CountryCode, State, City, Year, Month, DayOfWeek, Hour]
# Index: []
#
# DataFrame after removing outliers:
#    OrgId DetectorId AlertTitle           Category   IncidentGrade EntityType  \
# 0  other      other      other              other  BenignPositive       User
# 1      3          2          2  CommandAndControl  BenignPositive    Machine
# 2  other      other      other              other  BenignPositive      other
# 3  other          0          0      InitialAccess   FalsePositive      other
# 4  other      other      other              other  BenignPositive       User
#
#   EvidenceRole ApplicationName OSFamily OSVersion CountryCode State   City  \
# 0     Impacted            3421        5        66         242  1445  10630
# 1     Impacted            3421        0         0         242  1445  10630
# 2      Related            3421        5        66         242  1445  10630
# 3      Related            3421        5        66         242  1445  10630
# 4     Impacted            3421        5        66         242  1445  10630
#
#    Year Month DayOfWeek   Hour
# 0  2024     6         1  other
# 1  2024     6         0  other
# 2  2024     6     other  other
# 3  2024     6         2  other
# 4  2024     6         3     17
#
# Cleaned data saved to C:\Users\Elakkiya\Downloads\microsoft cybersecurity\top_n_categories_cleaned_testing_1.csv

# %%
import pandas as pd

# Define file paths
input_file_path =r"C:\Users\Elakkiya\Downloads\microsoft cybersecurity\top_n_categories_cleaned_testing_1.csv"
output_file_path = r"C:\Users\Elakkiya\Downloads\microsoft cybersecurity\top_n_categories_encoded_testing.csv"

# Define the number of top categories to retain and the replacement value for others
top_n_categories = 5
replacement_value = 6

# Function to encode top categories and replace others
def encode_categories(df, top_n=5, replacement_val=6):
    # Convert all integer columns to categorical
    for col in df.select_dtypes(include=['int64', 'float64']).columns:
        df[col] = df[col].astype('category')
    
    # Apply the encoding to each categorical column
    for col in df.select_dtypes(include=['category', 'object']).columns:
        # Convert to category type if not already
        df[col] = df[col].astype('category')
        category_counts = df[col].value_counts()
        top_categories = list(category_counts.nlargest(top_n).index)
        
        # Add 'Other' to the list of categories if not already present
        if 'Other' not in top_categories:
            top_categories.append('Other')
        
        # Ensure all categories are strings for consistent sorting and mapping
        top_categories = [str(cat) for cat in top_categories]
        
        # Create a manual mapping for label encoding, ensuring continuous integers
        unique_categories = sorted(top_categories)
        if 'Other' in unique_categories:
            unique_categories.remove('Other')
            unique_categories.append('Other')
        
        # Create the manual mapping
        manual_mapping = {category: i for i, category in enumerate(unique_categories)}
        
        # Add 'Other' to the Categorical type
        df[col] = df[col].cat.add_categories(['Other'])
        
        # Replace categories not in top_n with 'Other'
        df[col] = df[col].apply(lambda x: str(x) if str(x) in top_categories else 'Other')
        
        # Apply manual label encoding
        df[col] = df[col].map(manual_mapping)
        
        # Fill NaN values with the replacement value
        df[col] = df[col].fillna(manual_mapping['Other']).astype(int)
    
    return df

# Process the CSV file in chunks
chunk_size = 500000  # Adjust the chunk size as needed
chunks = []

for chunk in pd.read_csv(input_file_path, chunksize=chunk_size, low_memory=False):
    chunk_encoded = encode_categories(chunk, top_n=top_n_categories, replacement_val=replacement_value)
    chunks.append(chunk_encoded)

# Concatenate all chunks
df_encoded = pd.concat(chunks, axis=0)

# Save the processed DataFrame with encoded categories
df_encoded.to_csv(output_file_path, index=False)

# Display the processed DataFrame
print("\nProcessed DataFrame with encoded categories:")
print(df_encoded.head())
print(f"Shape of processed DataFrame: {df_encoded.shape}")

# Display the number of unique values per column after encoding
print("\nNumber of unique values per column after encoding:")
for col in df_encoded.columns:
    num_unique_values = df_encoded[col].nunique()
    print(f"{col}: {num_unique_values}")

# Check unique values in 'IncidentGrade'
unique_values = df_encoded['IncidentGrade'].unique()
print("\nUnique values in 'IncidentGrade':")
print(unique_values)
# Out:
# Processed DataFrame with encoded categories:
#    OrgId  DetectorId  AlertTitle  Category  IncidentGrade  EntityType  \
# 0      4           4           4         4              0           3
# 1      5           2           2         0              0           1
# 2      4           4           4         4              0           4
# 3      4           0           0         2              1           4
# 4      4           4           4         4              0           3
#
#    EvidenceRole  ApplicationName  OSFamily  OSVersion  CountryCode  State  \
# 0             0                3         4          3            3      2
# 1             0                3         0          0            3      2
# 2             1                3         4          3            3      2
# 3             1                3         4          3            3      2
# 4             0                3         4          3            3      2
#
#    City  Year  Month  DayOfWeek  Hour
# 0     2     1      3          1     4
# 1     2     1      3          0     4
# 2     2     1      3          4     4
# 3     2     1      3          2     4
# 4     2     1      3          3     5
# Shape of processed DataFrame: (3922695, 17)
#
# Number of unique values per column after encoding:
# OrgId: 6
# DetectorId: 6
# AlertTitle: 6
# Category: 6
# IncidentGrade: 3
# EntityType: 6
# EvidenceRole: 2
# ApplicationName: 6
# OSFamily: 5
# OSVersion: 6
# CountryCode: 6
# State: 6
# City: 6
# Year: 2
# Month: 6
# DayOfWeek: 6
# Hour: 6
#
# Unique values in 'IncidentGrade':
# [0 1 2]

# %%
import pandas as pd
from sklearn.feature_selection import SelectKBest, chi2

# Read the CSV file
file_path = r"C:\Users\Elakkiya\Downloads\microsoft cybersecurity\top_n_categories_encoded_testing.csv"
df = pd.read_csv(file_path)

# Drop the 'Year' column
if 'Year' in df.columns:
    df.drop(columns=['Year'], inplace=True)
    print("Dropped 'Year' column.")
else:
    print("'Year' column not found in the dataset.")

# Define the features (X) and the target (y)
X = df.drop(columns=['IncidentGrade'])
y = df['IncidentGrade']

# Perform Chi-Square test
chi2_selector = SelectKBest(chi2, k='all')
chi2_selector.fit(X, y)

# Create DataFrame to view scores and p-values
chi2_scores = pd.DataFrame({
    'Feature': X.columns,
    'Chi2 Score': chi2_selector.scores_,
    'P-value': chi2_selector.pvalues_
})

# Sort by Chi2 Score
chi2_scores = chi2_scores.sort_values(by='Chi2 Score', ascending=False)

# Print Chi2 Scores and P-values
print(chi2_scores)

# Select features based on Chi-Square p-values
selected_features_chi = chi2_scores[chi2_scores['P-value'] < 0.05]['Feature'].tolist()
print("Selected Features:", selected_features_chi)

# Create a DataFrame with the selected features and include the target variable
df_selected_features = df[selected_features_chi + ['IncidentGrade']]

# Save the selected features to a new CSV file
output_file_path = r"C:\Users\Elakkiya\Downloads\microsoft cybersecurity\selected_features_testing_2.csv"
df_selected_features.to_csv(output_file_path, index=False)
print(f"Selected features saved to {output_file_path}")
# Out:
# Dropped 'Year' column.
#             Feature     Chi2 Score        P-value
# 2        AlertTitle  403529.211135   0.000000e+00
# 0             OrgId  385835.162827   0.000000e+00
# 1        DetectorId  273596.602925   0.000000e+00
# 5      EvidenceRole   53867.596599   0.000000e+00
# 4        EntityType   21051.747123   0.000000e+00
# 3          Category   13906.299962   0.000000e+00
# 11             City   13207.917407   0.000000e+00
# 10            State   11727.013271   0.000000e+00
# 12            Month    2980.420409   0.000000e+00
# 13        DayOfWeek    2645.199986   0.000000e+00
# 14             Hour    2139.855359   0.000000e+00
# 7          OSFamily    1541.030522   0.000000e+00
# 8         OSVersion    1300.922111  3.223687e-283
# 9       CountryCode     994.641174  1.038516e-216
# 6   ApplicationName     185.946724   4.189691e-41
# Selected Features: ['AlertTitle', 'OrgId', 'DetectorId', 'EvidenceRole', 'EntityType', 'Category', 'City', 'State', 'Month', 'DayOfWeek', 'Hour', 'OSFamily', 'OSVersion', 'CountryCode', 'ApplicationName']
# Selected features saved to C:\Users\Elakkiya\Downloads\microsoft cybersecurity\selected_features_testing_2.csv

# %%
import pandas as pd

# Define the file path and the desired column order
file_path = r"C:\Users\Elakkiya\Downloads\microsoft cybersecurity\selected_features_testing_2.csv"
desired_column_order = ['OrgId', 'AlertTitle', 'DetectorId', 'EvidenceRole', 'Category', 'EntityType', 'City', 'State', 'Hour', 'OSFamily', 'OSVersion', 'CountryCode', 'Month', 'ApplicationName', 'DayOfWeek', 'IncidentGrade']

# Read the CSV file
df = pd.read_csv(file_path)

# Reorder the columns
df = df[desired_column_order]

# Save the DataFrame with the reordered columns to a new CSV file
output_file_path = r"C:\Users\Elakkiya\Downloads\microsoft cybersecurity\selected_features_testing_2_ordered.csv"
df.to_csv(output_file_path, index=False)
print(f"Data with reordered columns saved to {output_file_path}")
# Out:
# Data with reordered columns saved to C:\Users\Elakkiya\Downloads\microsoft cybersecurity\selected_features_testing_2_ordered.csv
